# %% [markdown]
# # 1.CLASIC07（bin+hdr转化为WGS84投影下的图像）（图像时间：）

# %%
# 将TIF数据处理成0.1°的点来计算（跨度比较大，可以实现，对原数据制作大于0掩膜）

# %% [markdown]
# # 2.SMAPVEX 08（fst+hdr）

# %%
# Out:
# ^C

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import rasterio
#       2 import numpy as np
#       4 # 文件路径
#
# ModuleNotFoundError: No module named 'rasterio'
